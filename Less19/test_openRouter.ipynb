# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv(override=True)

OPENAI_API_KEY_OP = os.getenv('OPENAI_API_KEY_OP')
BASE_URL = "https://openrouter.ai/api/v1"

# %%
# MODEL = "moonshotai/kimi-k2"
MODEL = "openai/gpt-4.1-nano"

client = OpenAI(
                base_url=BASE_URL,
                api_key=OPENAI_API_KEY_OP,
                )

completion = client.chat.completions.create(
                                            extra_body={},
                                            model=MODEL,
                                            messages=[
                                                {
                                                "role": "user",
                                                "content": "What is the meaning of life?"
                                                }
                                            ]
                                            )
print(completion.choices[0].message.content)
# Out:
# The question "What is the meaning of life?" is one of the most profound and timeless inquiries. Different perspectives offer various interpretations:
#
# - **Philosophical**: Many philosophers suggest that life's meaning is something each individual creates through their actions, relationships, and pursuits.
# - **Religious and Spiritual**: Many religious traditions see life's purpose as fulfilling a divine plan, spiritual growth, or attaining an afterlife or enlightenment.
# - **Personal**: For some, meaning is found through personal happiness, love, connection, achievement, or contributing to others.
# - **Scientific and Existential**: From a scientific perspective, life’s purpose may not be inherent but is something humans assign to their existence.
#
# Ultimately, the meaning of life is often considered a subjective and personal journey, influenced by individual beliefs, values, and experiences. What resonates most deeply varies from person to person.
