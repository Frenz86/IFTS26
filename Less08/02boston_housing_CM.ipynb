# %% [markdown]
# # Boston Housing Dataset

# %% [markdown]
# <img src= "https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/boston.jpg" width=1000>

# %% [markdown]
# The Boston data frame has 506 rows and 14 columns.This dataframe contains the following columns:
#
#
# CRIM  = per capita crime rate by town.
#
# ZN = proportion of residential land zoned for lots over 25,000 sq.ft.
#
# INDUS = proportion of non-retail business acres per town.
#
# CHAS = Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# NOX = nitrogen oxides concentration (parts per 10 million).
#
# RM = average number of rooms per dwelling.
#
# AGE = proportion of owner-occupied units built prior to 1940.
#
# DIS = weighted mean of distances to five Boston employment centres.
#
# RAD = index of accessibility to radial highways.
#
# TAX = full-value property-tax rate per $10,000.
#
# PTRATIO = pupil-teacher ratio by town.
#
# B = 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#
# LSTAT = lower status of the population (percent).
#
# price = median value of owner-occupied homes in $1000s
#
# ** Price is the TARGET variable **

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# !wget https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/boston_houses.csv
# Out:
# --2026-04-21 14:43:24--  https://frenzy86.s3.eu-west-2.amazonaws.com/IFAO/boston_houses.csv
# Resolving frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)... 3.5.244.38, 3.5.245.40, 3.5.246.105, ...
# Connecting to frenzy86.s3.eu-west-2.amazonaws.com (frenzy86.s3.eu-west-2.amazonaws.com)|3.5.244.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35230 (34K) [text/csv]
# Saving to: ‘boston_houses.csv’
#
# boston_houses.csv   100%[===================>]  34.40K  --.-KB/s    in 0.008s
#
# 2026-04-21 14:43:24 (4.03 MB/s) - ‘boston_houses.csv’ saved [35230/35230]

# %%
data = pd.read_csv("boston_houses.csv")
data.rename(columns={'MEDV': 'Price'}, inplace=True)
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
data.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# LSTAT    506.0   12.653063    7.141062    1.73000    6.950000   11.36000
# Price    506.0   22.532806    9.197104    5.00000   17.025000   21.20000
#
#                 75%       max
# CRIM       3.677083   88.9762
# ZN        12.500000  100.0000
# INDUS     18.100000   27.7400
# CHAS       0.000000    1.0000
# NOX        0.624000    0.8710
# RM         6.623500    8.7800
# AGE       94.075000  100.0000
# DIS        5.188425   12.1265
# RAD       24.000000   24.0000
# TAX      666.000000  711.0000
# PTRATIO   20.200000   22.0000
# B        396.225000  396.9000
# LSTAT     16.955000   37.9700
# Price     25.000000   50.0000

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue='TAX')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# CREARE VARIABILI CATEGORICHE PER VARIABILI CONTINUE E VISUALIZZARLE

# %%
df_cat=data.copy()

# %%
def get_age_category(x):
    if x < 50:
        return 'New'
    elif 50 <= x < 85:
        return 'Old'
    else:
        return 'Very_Old'

df_cat['AGE_category'] = df_cat['AGE'].apply(get_age_category)

# %%
df_cat.groupby('AGE_category').size()
# Out:
# AGE_category
# New         147
# Old         149
# Very_Old    210
# dtype: int64

# %%
sns.violinplot(x='LSTAT', y='AGE_category', data=df_cat, order=['New', 'Old','Very_Old'],hue='AGE_category');

# %%
sns.pairplot(df_cat, hue='AGE_category',hue_order=['New', 'Old','Very_Old']);
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
############ fine esperimento

# %%
# define numeric and categorical columns
num_col = data.describe().columns.tolist()
all_col = data.columns.tolist()
obj_col = [i for i in all_col if i not in num_col]

# %%
def viz(df,types):
    num = df
    f = pd.melt(num, value_vars=num)
    g = sns.FacetGrid(f, col="variable",  col_wrap=4,
                      sharex=False, sharey=False,height=2.5)
    g = g.map(types, "value")
    plt.show()
    return (g)
# histogram visualization
viz(data[num_col], sns.distplot)

# %%
# !pip install --upgrade klib

# import klib
# klib.dist_plot(data)

# %%
# !pip install jupyter-summarytools -q

from summarytools import dfSummary
dfSummary(data)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.0 MB/s eta 0:00:00
# <style type="text/css">
# #T_98d49 thead>tr>th {
#   text-align: left;
# }
# #T_98d49_row0_col0, #T_98d49_row1_col0, #T_98d49_row2_col0, #T_98d49_row3_col0, #T_98d49_row4_col0, #T_98d49_row5_col0, #T_98d49_row6_col0, #T_98d49_row7_col0, #T_98d49_row8_col0, #T_98d49_row9_col0, #T_98d49_row10_col0, #T_98d49_row11_col0, #T_98d49_row12_col0, #T_98d49_row13_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_98d49_row0_col1, #T_98d49_row1_col1, #T_98d49_row2_col1, #T_98d49_row3_col1, #T_98d49_row4_col1, #T_98d49_row5_col1, #T_98d49_row6_col1, #T_98d49_row7_col1, #T_98d49_row8_col1, #T_98d49_row9_col1, #T_98d49_row10_col1, #T_98d49_row11_col1, #T_98d49_row12_col1, #T_98d49_row13_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_98d49_row0_col2, #T_98d49_row1_col2, #T_98d49_row2_col2, #T_98d49_row3_col2, #T_98d49_row4_col2, #T_98d49_row5_col2, #T_98d49_row6_col2, #T_98d49_row7_col2, #T_98d49_row8_col2, #T_98d49_row9_col2, #T_98d49_row10_col2, #T_98d49_row11_col2, #T_98d49_row12_col2, #T_98d49_row13_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_98d49_row0_col3, #T_98d49_row1_col3, #T_98d49_row2_col3, #T_98d49_row3_col3, #T_98d49_row4_col3, #T_98d49_row5_col3, #T_98d49_row6_col3, #T_98d49_row7_col3, #T_98d49_row8_col3, #T_98d49_row9_col3, #T_98d49_row10_col3, #T_98d49_row11_col3, #T_98d49_row12_col3, #T_98d49_row13_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_98d49_row0_col4, #T_98d49_row1_col4, #T_98d49_row2_col4, #T_98d49_row3_col4, #T_98d49_row4_col4, #T_98d49_row5_col4, #T_98d49_row6_col4, #T_98d49_row7_col4, #T_98d49_row8_col4, #T_98d49_row9_col4, #T_98d49_row10_col4, #T_98d49_row11_col4, #T_98d49_row12_col4, #T_98d49_row13_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_98d49_row0_col5, #T_98d49_row1_col5, #T_98d49_row2_col5, #T_98d49_row3_col5, #T_98d49_row4_col5, #T_98d49_row5_col5, #T_98d49_row6_col5, #T_98d49_row7_col5, #T_98d49_row8_col5, #T_98d49_row9_col5, #T_98d49_row10_col5, #T_98d49_row11_col5, #T_98d49_row12_col5, #T_98d49_row13_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_98d49" class="dataframe">
#   <caption><strong>Data Frame Summary</strong><br>data<br>Dimensions: 506 x 14<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_98d49_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_98d49_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_98d49_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_98d49_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_98d49_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_98d49_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_98d49_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_98d49_row0_col1" class="data row0 col1" ><strong>CRIM</strong><br>[float64]</td>
#       <td id="T_98d49_row0_col2" class="data row0 col2" >Mean (sd) : 3.6 (8.6)<br>min < med < max:<br>0.0 < 0.3 < 89.0<br>IQR (CV) : 3.6 (0.4)</td>
#       <td id="T_98d49_row0_col3" class="data row0 col3" >504 distinct values</td>
#       <td id="T_98d49_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_98d49_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_98d49_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_98d49_row1_col1" class="data row1 col1" ><strong>ZN</strong><br>[float64]</td>
#       <td id="T_98d49_row1_col2" class="data row1 col2" >Mean (sd) : 11.4 (23.3)<br>min < med < max:<br>0.0 < 0.0 < 100.0<br>IQR (CV) : 12.5 (0.5)</td>
#       <td id="T_98d49_row1_col3" class="data row1 col3" >26 distinct values</td>
#       <td id="T_98d49_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_98d49_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_98d49_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_98d49_row2_col1" class="data row2 col1" ><strong>INDUS</strong><br>[float64]</td>
#       <td id="T_98d49_row2_col2" class="data row2 col2" >Mean (sd) : 11.1 (6.9)<br>min < med < max:<br>0.5 < 9.7 < 27.7<br>IQR (CV) : 12.9 (1.6)</td>
#       <td id="T_98d49_row2_col3" class="data row2 col3" >76 distinct values</td>
#       <td id="T_98d49_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_98d49_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_98d49_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_98d49_row3_col1" class="data row3 col1" ><strong>CHAS</strong><br>[int64]</td>
#       <td id="T_98d49_row3_col2" class="data row3 col2" >1. 0<br>2. 1</td>
#       <td id="T_98d49_row3_col3" class="data row3 col3" >471 (93.1%)<br>35 (6.9%)</td>
#       <td id="T_98d49_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_98d49_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_98d49_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_98d49_row4_col1" class="data row4 col1" ><strong>NOX</strong><br>[float64]</td>
#       <td id="T_98d49_row4_col2" class="data row4 col2" >Mean (sd) : 0.6 (0.1)<br>min < med < max:<br>0.4 < 0.5 < 0.9<br>IQR (CV) : 0.2 (4.8)</td>
#       <td id="T_98d49_row4_col3" class="data row4 col3" >81 distinct values</td>
#       <td id="T_98d49_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_98d49_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_98d49_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_98d49_row5_col1" class="data row5 col1" ><strong>RM</strong><br>[float64]</td>
#       <td id="T_98d49_row5_col2" class="data row5 col2" >Mean (sd) : 6.3 (0.7)<br>min < med < max:<br>3.6 < 6.2 < 8.8<br>IQR (CV) : 0.7 (8.9)</td>
#       <td id="T_98d49_row5_col3" class="data row5 col3" >446 distinct values</td>
#       <td id="T_98d49_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_98d49_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_98d49_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_98d49_row6_col1" class="data row6 col1" ><strong>AGE</strong><br>[float64]</td>
#       <td id="T_98d49_row6_col2" class="data row6 col2" >Mean (sd) : 68.6 (28.1)<br>min < med < max:<br>2.9 < 77.5 < 100.0<br>IQR (CV) : 49.0 (2.4)</td>
#       <td id="T_98d49_row6_col3" class="data row6 col3" >356 distinct values</td>
#       <td id="T_98d49_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_98d49_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_98d49_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_98d49_row7_col1" class="data row7 col1" ><strong>DIS</strong><br>[float64]</td>
#       <td id="T_98d49_row7_col2" class="data row7 col2" >Mean (sd) : 3.8 (2.1)<br>min < med < max:<br>1.1 < 3.2 < 12.1<br>IQR (CV) : 3.1 (1.8)</td>
#       <td id="T_98d49_row7_col3" class="data row7 col3" >412 distinct values</td>
#       <td id="T_98d49_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_98d49_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_98d49_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_98d49_row8_col1" class="data row8 col1" ><strong>RAD</strong><br>[int64]</td>
#       <td id="T_98d49_row8_col2" class="data row8 col2" >1. 24<br>2. 5<br>3. 4<br>4. 3<br>5. 6<br>6. 8<br>7. 2<br>8. 1<br>9. 7</td>
#       <td id="T_98d49_row8_col3" class="data row8 col3"

# %%
corr = data.corr(numeric_only=True)

import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Regressione con tutte le Features

# %%
## STEP1 DEFINIZIONE DI INPUT E OUTPUT
target = 'Price'
X = data.drop(columns=[target])
y = data[target]

# %%
X.ndim
# Out:
# 2

# %%
## STEP2 TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=667,
                                                   )

# %%
## STEP3 MODELLAZIONE (REGRESSION)
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
## STEP4 PREDIZIONE
y_pred = model.predict(X_test)

# %%
## STEP5 VERIFICA METRICHE (for Regression)
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error,mean_squared_error

r2 = r2_score(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
rmse = root_mean_squared_error(y_test,y_pred)

print(f'R2 score {r2}')
print(f'MSE score {mse}')
print(f'MAE score {mae}')
print(f'RMSE score {rmse}')
# Out:
# R2 score 0.6113097827490286
# MSE score 34.48551396483917
# MAE score 3.6837720318116576
# RMSE score 5.872436799561079

# %% [markdown]
# ### Feature Selection with correlation

# %%
corrmat = data.corr()
corrmat
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# Price   -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT     Price
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# Price    0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
plt.figure(figsize = (12, 10))
sns.heatmap(corrmat, annot = True, annot_kws={'size': 12});

# %%
corrmat.index.values
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT', 'Price'], dtype=object)

# %%
##1
def getCorrelatedFeature(corrdata, threshold):
    feature = []
    value = []

    for i, index in enumerate(corrdata.index):
        if abs(corrdata[index])> threshold:
            feature.append(index)
            value.append(corrdata[index])

    df = pd.DataFrame(data = value, index = feature, columns=['Corr Value'])
    return df

# %%
# Prendi la colonna Price del dataframe data, applica la treshold e includi in questo dataframe le features
threshold = 0.45
corr_value = getCorrelatedFeature(corrmat['Price'], threshold)
corr_value
# Out:
#          Corr Value
# INDUS     -0.483725
# RM         0.695360
# TAX       -0.468536
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Price      1.000000

# %%
corr_value.index.values
# Out:
# array(['INDUS', 'RM', 'TAX', 'PTRATIO', 'LSTAT', 'Price'], dtype=object)

# %%
correlated_data = data[corr_value.index]
correlated_data
# Out:
#      INDUS     RM  TAX  PTRATIO  LSTAT  Price
# 0     2.31  6.575  296     15.3   4.98   24.0
# 1     7.07  6.421  242     17.8   9.14   21.6
# 2     7.07  7.185  242     17.8   4.03   34.7
# 3     2.18  6.998  222     18.7   2.94   33.4
# 4     2.18  7.147  222     18.7   5.33   36.2
# ..     ...    ...  ...      ...    ...    ...
# 501  11.93  6.593  273     21.0   9.67   22.4
# 502  11.93  6.120  273     21.0   9.08   20.6
# 503  11.93  6.976  273     21.0   5.64   23.9
# 504  11.93  6.794  273     21.0   6.48   22.0
# 505  11.93  6.030  273     21.0   7.88   11.9
#
# [506 rows x 6 columns]

# %%
correlated_data.shape
# Out:
# (506, 6)

# %%
sns.pairplot(correlated_data,height=2)
plt.tight_layout()

# %%
sns.heatmap(correlated_data.corr(), annot=True, annot_kws={'size': 12});

# %% [markdown]
# ## Shuffle and Split Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error,root_mean_squared_error

# %%
X = correlated_data.drop(labels=['Price'], axis = 1)
y = correlated_data['Price']

X
# Out:
#      INDUS     RM  TAX  PTRATIO  LSTAT
# 0     2.31  6.575  296     15.3   4.98
# 1     7.07  6.421  242     17.8   9.14
# 2     7.07  7.185  242     17.8   4.03
# 3     2.18  6.998  222     18.7   2.94
# 4     2.18  7.147  222     18.7   5.33
# ..     ...    ...  ...      ...    ...
# 501  11.93  6.593  273     21.0   9.67
# 502  11.93  6.120  273     21.0   9.08
# 503  11.93  6.976  273     21.0   5.64
# 504  11.93  6.794  273     21.0   6.48
# 505  11.93  6.030  273     21.0   7.88
#
# [506 rows x 5 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.2,
                                                    random_state = 667
                                                    )

# %%
X_train.shape, X_test.shape
# Out:
# ((404, 5), (102, 5))

# %% [markdown]
# ## Start train the model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
df = pd.DataFrame(data = [y_pred, y_test])
df = df.T
df.columns = ['predetti', 'reali_test']
df
# Out:
#       predetti  reali_test
# 0    22.020759        18.7
# 1    20.918932        18.5
# 2    30.655165        29.8
# 3     6.819269         9.7
# 4    22.483853        21.7
# ..         ...         ...
# 97   18.560542        27.5
# 98   23.012295        21.4
# 99   16.751238        15.6
# 100  22.363613        29.6
# 101  13.927185        15.2
#
# [102 rows x 2 columns]

# %%
length = y_pred.shape[0] #
x = np.linspace(0,length,length)


plt.figure(figsize=(15,10))
plt.plot(x, y_test, label='test')
plt.plot(x, y_pred, label='predetto')
plt.legend(loc=2);

# %% [markdown]
# ## Defining performance metrics

# %% [markdown]
# It is difficult to measure the quality of a given model without quantifying its performance over training and testing. This is typically done using some type of performance metric, whether it is through calculating some type of error, the goodness of fit, or some other useful measurement. For this project, you will be calculating the coefficient of determination, R2, to quantify your model's performance. The coefficient of determination for a model is a useful statistic in regression analysis, as it often describes how "good" that model is at making predictions.
#
# The values for R2 range from 0 to 1, which captures the percentage of squared correlation between the predicted and actual values of the target variable. A model with an R2 of 0 always fails to predict the target variable, whereas a model with an R2 of 1 perfectly predicts the target variable. Any value between 0 and 1 indicates what percentage of the target variable, using this model, can be explained by the features. A model can be given a negative R2 as well, which indicates that the model is no better than one that naively predicts the mean of the target variable.
#
# For the performance_metric function in the code cell below, you will need to implement the following:
#
# Use r2_score from sklearn.metrics to perform a performance calculation between y_true and y_predict. Assign the performance score to the score variable.

# %% [markdown]
# ## Regression Evaluation Metrics

# %% [markdown]
# Here are three common evaluation metrics for regression problems:
#
# Mean Absolute Error (MAE) is the mean of the absolute value of the errors:
#
# $$\frac 1n\sum_{i=1}^n|y_i-\hat{y}_i|$$
# Mean Squared Error (MSE) is the mean of the squared errors:
#
# $$\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2$$
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors:
#
# $$\sqrt{\frac 1n\sum_{i=1}^n(y_i-\hat{y}_i)^2}$$
# Comparing these metrics:
#
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.
# All of these are loss functions, because we want to minimize them.

# %%
from sklearn.metrics import r2_score

# %%
correlated_data.columns
# Out:
# Index(['INDUS', 'RM', 'TAX', 'PTRATIO', 'LSTAT', 'Price'], dtype='object')

# %%
score = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)

print('r2_score: ', score)
print('mae: ', mae)
print('mse: ', mse)
print('rmse: ', rmse)
# Out:
# r2_score:  0.5971252884177827
# mae:  3.9979819763532
# mse:  36.03788023808321
# rmse:  6.003155856554385

# %%
threshold = 0.40
corr_value = getCorrelatedFeature(corrmat['Price'], threshold)
corr_value
# Out:
#          Corr Value
# INDUS     -0.483725
# NOX       -0.427321
# RM         0.695360
# TAX       -0.468536
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Price      1.000000

# %%
##2
total_features = []
total_features_name = []
selected_correlation_value = []
r2_scores = []
r2_adjusted_scores = []
mae_values = []
mse_values = []
rmse_values = []

def performance_metrics(features, th, y_true, y_pred):
    n = len(y_true)
    p = len(features) - 1  # excluding the intercept

    r2 = r2_score(y_true, y_pred)
    adj_r2 = 1 - ((1 - r2) * (n - 1) / (n - p - 1))

    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = root_mean_squared_error(y_true, y_pred)

    total_features.append(len(features) - 1)
    total_features_name.append(str(features))
    selected_correlation_value.append(th)
    r2_scores.append(round(r2,2))
    r2_adjusted_scores.append(round(adj_r2,2))
    mae_values.append(round(mae,2))
    mse_values.append(round(mse,2))
    rmse_values.append(round(rmse,2))

    metrics_dataframe = pd.DataFrame(data=[total_features_name, total_features, selected_correlation_value,
                                           r2_scores, r2_adjusted_scores, mae_values, mse_values, rmse_values],
                                     index=['features name', '#feature', 'corr_value', 'R2', 'R2_adjusted', 'MAE', 'MSE', 'RMSE'])
    return metrics_dataframe.T

# %%
performance_metrics(correlated_data.columns.values, threshold, y_test, y_pred)
# Out:
#                                     features name #feature corr_value   R2  \
# 0  ['INDUS' 'RM' 'TAX' 'PTRATIO' 'LSTAT' 'Price']        5        0.4  0.6
#
#   R2_adjusted  MAE    MSE RMSE
# 0        0.58  4.0  36.04  6.0

# %% [markdown]
# ## regression plot of the features correlated with the price

# %%
rows = 3
cols = 2
fig, ax = plt.subplots(nrows=rows, ncols=cols, figsize = (12, 3))

col = correlated_data.columns
index = 0

for i in range(rows):
    for j in range(cols):
        sns.regplot(x = correlated_data[col[index]], y = correlated_data['Price'], ax = ax[i][j])
        index = index + 1
fig.tight_layout()

# %% [markdown]
# ### Let's find out other combination of columns to get better accuracy >60%

# %%
corrmat['Price']
# Out:
# CRIM      -0.388305
# ZN         0.360445
# INDUS     -0.483725
# CHAS       0.175260
# NOX       -0.427321
# RM         0.695360
# AGE       -0.376955
# DIS        0.249929
# RAD       -0.381626
# TAX       -0.468536
# PTRATIO   -0.507787
# B          0.333461
# LSTAT     -0.737663
# Price      1.000000
# Name: Price, dtype: float64

# %%
threshold = 0.50
corr_value = getCorrelatedFeature(corrmat['Price'], threshold)
corr_value
# Out:
#          Corr Value
# RM         0.695360
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Price      1.000000

# %%
correlated_data = data[corr_value.index]
correlated_data.head()
# Out:
#       RM  PTRATIO  LSTAT  Price
# 0  6.575     15.3   4.98   24.0
# 1  6.421     17.8   9.14   21.6
# 2  7.185     17.8   4.03   34.7
# 3  6.998     18.7   2.94   33.4
# 4  7.147     18.7   5.33   36.2

# %%
##3

def get_y_predict(corr_data):
    X = corr_data.drop(labels = ['Price'], axis = 1)
    y = corr_data['Price']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 667)
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return y_pred,y_test

# %%
y_pred,y_test = get_y_predict(correlated_data)

# %%
performance_metrics(correlated_data.columns.values, threshold, y_test, y_pred)
# Out:
#                                     features name #feature corr_value   R2  \
# 0  ['INDUS' 'RM' 'TAX' 'PTRATIO' 'LSTAT' 'Price']        5        0.4  0.6
# 1                ['RM' 'PTRATIO' 'LSTAT' 'Price']        3        0.5  0.6
#
#   R2_adjusted   MAE    MSE  RMSE
# 0        0.58   4.0  36.04   6.0
# 1        0.59  4.01  35.72  5.98

# %% [markdown]
# Let's find out other combination of columns to get better accuracy >70%

# %%
corrmat['Price']
# Out:
# CRIM      -0.388305
# ZN         0.360445
# INDUS     -0.483725
# CHAS       0.175260
# NOX       -0.427321
# RM         0.695360
# AGE       -0.376955
# DIS        0.249929
# RAD       -0.381626
# TAX       -0.468536
# PTRATIO   -0.507787
# B          0.333461
# LSTAT     -0.737663
# Price      1.000000
# Name: Price, dtype: float64

# %%
threshold = 0.60
corr_value = getCorrelatedFeature(corrmat['Price'], threshold)
corr_value
# Out:
#        Corr Value
# RM       0.695360
# LSTAT   -0.737663
# Price    1.000000

# %%
correlated_data = data[corr_value.index]
correlated_data.head()
# Out:
#       RM  LSTAT  Price
# 0  6.575   4.98   24.0
# 1  6.421   9.14   21.6
# 2  7.185   4.03   34.7
# 3  6.998   2.94   33.4
# 4  7.147   5.33   36.2

# %%
y_pred,y_test = get_y_predict(correlated_data)
performance_metrics(correlated_data.columns.values, threshold, y_test, y_pred)
# Out:
#                                     features name #feature corr_value    R2  \
# 0  ['INDUS' 'RM' 'TAX' 'PTRATIO' 'LSTAT' 'Price']        5        0.4   0.6
# 1                ['RM' 'PTRATIO' 'LSTAT' 'Price']        3        0.5   0.6
# 2                          ['RM' 'LSTAT' 'Price']        2        0.6  0.55
#
#   R2_adjusted   MAE    MSE  RMSE
# 0        0.58   4.0  36.04   6.0
# 1        0.59  4.01  35.72  5.98
# 2        0.54  4.43  40.08  6.33

# %%
threshold = 0.70
corr_value = getCorrelatedFeature(corrmat['Price'], threshold)
corr_value
# Out:
#        Corr Value
# LSTAT   -0.737663
# Price    1.000000

# %%
correlated_data = data[corr_value.index]
correlated_data.head()
# Out:
#    LSTAT  Price
# 0   4.98   24.0
# 1   9.14   21.6
# 2   4.03   34.7
# 3   2.94   33.4
# 4   5.33   36.2

# %%
y_pred,y_test = get_y_predict(correlated_data)
performance_metrics(correlated_data.columns.values, threshold, y_test, y_pred)
# Out:
#                                     features name #feature corr_value    R2  \
# 0  ['INDUS' 'RM' 'TAX' 'PTRATIO' 'LSTAT' 'Price']        5        0.4   0.6
# 1                ['RM' 'PTRATIO' 'LSTAT' 'Price']        3        0.5   0.6
# 2                          ['RM' 'LSTAT' 'Price']        2        0.6  0.55
# 3                               ['LSTAT' 'Price']        1        0.7  0.46
#
#   R2_adjusted   MAE    MSE  RMSE
# 0        0.58   4.0  36.04   6.0
# 1        0.59  4.01  35.72  5.98
# 2        0.54  4.43  40.08  6.33
# 3        0.46  4.93  48.09  6.93

# %%
## Best R2_adjusted is with 3 features: 'RM' 'PTRATIO' 'LSTAT'

# %%
## Scegliamo soluzione a 3 variabili
X = data[['RM','PTRATIO','LSTAT']]
y = data['Price']

X
# Out:
#         RM  PTRATIO  LSTAT
# 0    6.575     15.3   4.98
# 1    6.421     17.8   9.14
# 2    7.185     17.8   4.03
# 3    6.998     18.7   2.94
# 4    7.147     18.7   5.33
# ..     ...      ...    ...
# 501  6.593     21.0   9.67
# 502  6.120     21.0   9.08
# 503  6.976     21.0   5.64
# 504  6.794     21.0   6.48
# 505  6.030     21.0   7.88
#
# [506 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.2,
                                                    random_state = 667
                                                    )

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
import joblib

joblib.dump(model,'lr_boston.pkl')
# Out:
# ['lr_boston.pkl']

# %%
loaded_model = joblib.load('lr_boston.pkl')
loaded_model
# Out:
# LinearRegression()

# %%
loaded_model.predict([[6.5, 15.3,5]])[0]
# Out:
# np.float64(30.87040997130472)

# %%
model.intercept_
# Out:
# np.float64(19.082310457569708)

# %%
model.coef_
# Out:
# array([ 4.35588773, -0.87654899, -0.62279423])

# %%
#y' = b0+b1*x1+b2*x2+b3*x3

# %% [markdown]
# # Normalization and Standardization

# %% [markdown]
# Standardization = Gaussian with zero mean and unit variance.

# %% [markdown]
#  Z is rescaled such that any specific z will now be 0 ≤ z ≤ 1, and is done through this formula:

# %% [markdown]
# $$ z = \frac {x−min(x)} {max(x)−min(x)}$$

# %%
## Deprecata
# model = LinearRegression(normalize=True)
# model.fit(X_train, y_train)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.2,
                                                    random_state = 667
                                                    )

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

ss = StandardScaler()
X_train_norm = ss.fit_transform(X_train)
X_test_norm = ss.transform(X_test)

# %%
model_norm = LinearRegression()

model_norm.fit(X_train_norm,y_train)
y_pred = model_norm.predict(X_test_norm)
r2_score(y_test, y_pred)
# Out:
# 0.6006320504859002

# %% [markdown]
# ## Cross Validation

# %%
from IPython.display import Image
Image(url='https://frenzy86.s3.eu-west-2.amazonaws.com/fav/cross_val.png',width=600,height=300)
# Out:
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/fav/cross_val.png" width="600" height="300"/>

# %%
df = pd.read_csv("boston_houses.csv")
## fix the rename with inplace
#data.rename(columns={'oldName1': 'newName1'}, inplace=True)
df.rename(columns={'MEDV': 'Price'}, inplace=True) #preview
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %%
X = df.drop('Price',axis=1)
y = df['Price']

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3,
                                                    random_state=667
                                                    )
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test) #R^2
# Out:
# 0.6113097827490286

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, X, y, cv=5,scoring='r2')
scores
# Out:
# array([ 0.63919994,  0.71386698,  0.58702344,  0.07923081, -0.25294154])

# %%
np.mean(scores)
# Out:
# np.float64(0.3532759243958849)
