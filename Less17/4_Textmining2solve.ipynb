# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/python/positive.png" width="400" align="center">

# %%
path = 'https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/textsentiment.csv'
