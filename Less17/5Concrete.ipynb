# %% [markdown]
# ## Concrete Compression

# %% [markdown]
# <img src="https://frenzy86.s3.dualstack.eu-west-2.amazonaws.com/python/data/concrete.png" width="1050" align="center">

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
path = 'https://frenzy86.s3.dualstack.eu-west-2.amazonaws.com/python/data/Concrete_Data.xlsx'
#target compressive strength
